# %% [markdown]
# # Object Detection

# %% [markdown]
# _Author:_ @AdameBf

# %%
import skimage
import matplotlib.pyplot as plt

# %% [markdown]
# Let's start by loading an image within the dataset.

# %%
example_image = skimage.io.imread("test/0a0e115419660a12.jpg")
print(example_image.shape)
plt.imshow(example_image)
plt.show()
# Out:
# (683, 1024, 3)

# %% [markdown]
# Unsurprisingly, the images are 3-channelled according to the value of ``example_image.shape[-1]``.
